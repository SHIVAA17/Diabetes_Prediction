# %% [markdown]
# <a href="https://colab.research.google.com/github/SHIVAA17/Diabetes_prediction/blob/main/task3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Author: Shivkumar Hudge </h1>
# The Sparks Foundation: Data Science And Business Analytics Internship
#
# ![Capture3.PNG](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Reading the dataset
dataset = pd.read_csv('SampleSuperstore.csv')
dataset
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
dataset.shape
# Out:
# (9994, 13)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
#to get count of no of null values
dataset.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
#to check duplicate values
dataset.duplicated().sum()
# Out:
# 17

# %%
dataset.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
#Ship Mode
plt.figure(figsize=(9,5))
sns.countplot(x='Ship Mode',data = dataset)

# %%
#Removing Unecessary Columns
dataset.drop(['Postal Code'],axis =1,inplace=True)

# %%
#Removing Unecessary Columns
dataset.drop(['Ship Mode'],axis =1,inplace=True)

# %%
#
sns.pairplot(data = dataset,hue='Category')

# %%
dataset.shape
# Out:
# (9994, 11)

# %%
# By state
plt.figure(figsize=(15,10))
plt.xticks(rotation=90)
sns.countplot(x='State',data = dataset)

# %%
#region
dataset['Region'].value_counts()

dataset['Region'].value_counts().plot.pie(autopct="%1.1f%%")

# %%
#Quantity
plt.figure(figsize=(15,10))
plt.xticks(rotation=90)
sns.countplot(x='Quantity',data = dataset)

# %%
#Quantity
plt.figure(figsize=(15,10))
plt.xticks(rotation=90)
sns.countplot(x='Sub-Category',data = dataset)

# %%
plt.figure(figsize=(9,15))
plt.bar(dataset['Sub-Category'],dataset['Sales'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(9,15))
plt.bar(dataset['Sub-Category'],dataset['Profit'])
plt.xticks(rotation=90)
plt.show()

# %%
#heatmap
d_heat = dataset.corr()
sns.heatmap(d_heat,annot=True,cmap='Blues')

# %% [markdown]
# Quantity

# %%
plt.figure(figsize=(9,5))
sns.countplot(x='Category',hue='Segment',data=dataset)
plt.show()

# %%
plt.bar(dataset['Category'],dataset['Sales'])
plt.title('category vs sales')
plt.xlabel('category')
plt.ylabel('Sales')
plt.show()

# %%
plt.bar(dataset['Category'],dataset['Profit'])
plt.title('category vs Profit')
plt.xlabel('category')
plt.ylabel('Profit')
plt.show()

# %%
dataset['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
plt.bar(dataset['Segment'],dataset['Sales'])
# Out:
# <BarContainer object of 9994 artists>

# %%
dataset.plot.scatter(x='Sales',y='Profit',s=5)

# %%
dataset.plot.scatter(x='Discount',y='Profit',)

# %%
plt.figure(figsize = (11,5))
sns.lineplot('Sales', 'Profit', data = dataset, color = 'blue', label= 'Profit')
plt.legend()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize = (11,5))
sns.lineplot('Segment','Sales', data = dataset, color = 'blue', label= 'Sales')
plt.legend()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# <h1> Summary </h1>

# %% [markdown]
# <p> 1)The most Prefered mode of shipment is the standard and least prefered mode of shipment was the same day.</p>
# <p>2) The average order quantity is around 2 to 3 </p>
# <p>3)Sales and profit has the highest positive correlation.we can conclude that as sales increase profit also increases.</p>
#
# <p>4) Max Sales:Machines  and Min Sales:Fasteners</p>
# <p>5) Max Profit:Copiers  and Min Profit:Fasteners
